# %%
# %matplotlib inline
import skutils
import pandas as pd

TRAIN_DATA = "../../data/train.csv"
TEST_DATA = "../../data/test.csv"

# %%
# Load the training data
train = pd.read_csv(TRAIN_DATA)

# Load the testing data
test = pd.read_csv(TEST_DATA)

# %%
# Print pretty stats about the training data set
skutils.pretty_stats(train, target_key='TARGET')
# Out:
# <h1>General</h1>
# <table><thead><tr><th>property</th><th>values</th></tr></thead><tbody><tr><td>Number of features</td><td>371</td></tr><tr><td>Number of Samples</td><td>76020</td></tr></tbody></table>
# <h1>Distribution per Target</h1>
# <table><thead><tr><th>target</th><th>count</th></tr></thead><tbody><tr><td>0</td><td>73012</td></tr><tr><td>1</td><td>3008</td></tr></tbody></table>
# <h1>Distribution</h1>
# ...

# %%
# Print pretty stats about the testing data set
skutils.pretty_stats(test)
# Out:
# <h1>General</h1>
# <table><thead><tr><th>property</th><th>values</th></tr></thead><tbody><tr><td>Number of features</td><td>370</td></tr><tr><td>Number of Samples</td><td>75818</td></tr></tbody></table>
# <h1>Distribution</h1>
# ...

# %%
def transform(data):
    
    # Extract the ids
    ids = data['ID']
    
    # Extract the data
    X = data.drop(['TARGET', 'ID'],  axis=1)
    
    # Extract the labels
    y = data['TARGET']
    
    return ids, X, y

# %%
# Transform data
ids, X, y = transform(train)

# %%
X.describe()
# Out:
#                 var3         var15  imp_ent_var16_ult1  \
# count   76020.000000  76020.000000        76020.000000
# mean    -1523.199277     33.212865           86.208265
# std     39033.462364     12.956486         1614.757313
# min   -999999.000000      5.000000            0.000000
# 25%         2.000000     23.000000            0.000000
# 50%         2.000000     28.000000            0.000000
# 75%         2.000000     40.000000            0.000000
# max       238.000000    105.000000       210000.000000
#
#        imp_op_var39_comer_ult1  imp_op_var39_comer_ult3  \
# count             76020.000000             76020.000000
# mean                 72.363067               119.529632
# std                 339.315831               546.266294
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# ...

# %%
skutils.tsne_plot(X.values, y.values, n_samples=5000)
# Out:
# /home/ckoerner/.local/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
