# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

import utils
import skutils
import pandas as pd

TRAIN_DATA = "../../data/train.csv"

# Load the training data
train = pd.read_csv(TRAIN_DATA)

# %%
# Get uniques
uniques = train.apply(lambda x: len(x.unique()))

def transform(data, threshold_unimportant=0.0000001):
    
    cols_emtpy = list(uniques[uniques == 1].index.values)
    
    # We have to remove the correlated ones by hand
    # because there can be multiple correlations with one column
    cols_correlated = [
        'ind_var1', 'ind_var1_0',
        'ind_var5',
        'ind_var6', 'ind_var6_0', 'num_var6',
        'ind_var8', 'ind_var8_0',
        'ind_var12',
        'ind_var13_corto', 'ind_var13_corto_0', 'ind_var13_medio', 'ind_var13_medio_0',
        'ind_var18', 'ind_var18_0', 'num_var18', 'num_var18_0',
        'ind_var20', 'ind_var20_0',
        'ind_var29', 'ind_var29_0',
        'ind_var24', 'ind_var24_0',
        'ind_var25_0', 'num_var25_0',
        'ind_var26_0', 'num_var26_0',
        'ind_var32_0', 'num_var32_0',
        'ind_var34', 'ind_var34_0', 'num_var34', 'num_var34_0',
        'ind_var37_0', 'num_var37_0',
        'ind_var39',
        'ind_var40', 'num_var40',
        'ind_var44',
        'num_var29_0',
        'num_var13_medio', 'num_var13_medio_0',
        'num_var7_emit_ult1',
        'num_var39',
        'num_var40_0',
        'num_var44_0',
        'saldo_var6',
        'saldo_var18',
        'saldo_var13_medio',
        'saldo_medio_var17_ult3',
        'saldo_medio_var33_ult1',
        'delta_imp_aport_var13_1y3', 'delta_imp_reemb_var13_1y3', 'delta_num_reemb_var13_1y3',
        'delta_imp_aport_var17_1y3', 'delta_imp_reemb_var17_1y3', 'delta_num_trasp_var17_in_1y3', 'delta_num_trasp_var17_out_1y3',
        'delta_imp_aport_var33_1y3', 'delta_imp_reemb_var33_1y3', 'delta_num_reemb_var33_1y3', 'delta_num_trasp_var33_out_1y3',
        'delta_imp_compra_var44_1y3', 'delta_imp_venta_var44_1y3',
        'delta_imp_trasp_var17_in_1y3', 'delta_imp_trasp_var17_out_1y3',
        'delta_imp_trasp_var33_in_1y3', 'delta_imp_trasp_var33_out_1y3',
        'imp_reemb_var17_hace3',
        'imp_reemb_var33_ult1', 'imp_trasp_var33_out_ult1',
        'num_med_var45_ult3',
        'imp_op_var39_efect_ult1',
        'imp_op_var39_efect_ult3',
        'imp_op_var39_ult1',
        'imp_amort_var18_ult1',
        'saldo_medio_var17_hace3', 'saldo_medio_var17_ult1',
        'saldo_medio_var13_medio_ult3',
    ]

    # Extract the ids
    ids = data['ID']
    
    # Extract the data
    X = data.drop(['ID'] + cols_emtpy + cols_correlated,  axis=1)
    if 'TARGET' in data.columns:
        X.drop('TARGET', axis=1, inplace=True)

    # Extract the labels
    y = data['TARGET'] if 'TARGET' in data.columns else None
    
    return ids, X, y

# %%
from sklearn.metrics import roc_auc_score

# Learning Rates with decay function
def learning_rates(steps, start=1, end=0, start_exp_x=0.0, end_exp_x=7.0):
    return end + np.exp(-np.linspace(start_exp_x, end_exp_x, steps)) * (start - end)

def cross_validate_xgb(X_train, y_train, params, fit_params={}, folds=None, scorer=roc_auc_score):

    if folds is None:
        folds = skutils.folds(y_train, n_folds=4, stratified=True)
    
    test_scores = []
    train_scores = []
    
    for train_idx, test_idx in folds:

        clf = xgb.XGBClassifier(**params)
        
        # Needs latest XGBoost from chaosmail
        # https://github.com/chaosmail/xgboost
        # Build Instructions: https://github.com/dmlc/xgboost/blob/master/doc/build.md
        # https://github.com/dmlc/xgboost/pull/1018
        clf.fit(X_train.values[train_idx], y_train.values[train_idx], verbose=False, **fit_params)
        
        # Predict the test output
        y_predict = clf.predict_proba(X_train.values[test_idx])[:,1]
        test_scores.append(scorer(y_train.values[test_idx], y_predict))
        
        # Predict the train output
        y_predict = clf.predict_proba(X_train.values[train_idx])[:,1]
        train_scores.append(scorer(y_train.values[train_idx], y_predict))
    
    return np.mean(test_scores), np.std(test_scores), np.mean(train_scores), np.std(train_scores)

# %% [markdown]
# # Create a XGB Classifier

# %%
from hyperopt import hp
import xgboost as xgb
import numpy as np

# Transform the training data
Ids_train, X, y = transform(train)

# In the end we will use this amount of estimators
n_total_estimators = 500
n_cv_estimators = 100

seed = 42

params = {
    'colsample_bytree': 0.98406117320608466,
    'max_depth': int(4.0),
    'min_child_weight': 4.0,
    'subsample': 0.80576464743565634,
    'n_estimators': n_cv_estimators,
    'seed': seed
}

learn_params = {
    'learning_rate_end': 0.08303127679504986,
    'learning_rate_start': 0.11158443875324964,
}

def iter_learning_rates(i, n): 
    return learning_rates(
        n_total_estimators, start=learn_params['learning_rate_start'], end=learn_params['learning_rate_end']
    )[i]
        

fit_params = {
    #'early_stopping_rounds': 20,
    'learning_rates': iter_learning_rates,
    'eval_metric': 'auc',
    #'eval_set': [(X_test.values, y_test.values)],
}
# eval_set: set that is used for watching the training performance

space = hp.choice('method', [
    ('random', {
        'seed': hp.quniform('seed', 1, 1000000, 1),
        'fzeros': hp.uniform('fzeros', 0.5, 1.0),
     }
    ),
])

# %% [markdown]
# # Find the best balance in the dataset

# %%
from hyperopt import fmin, rand, hp, STATUS_OK, Trials

def objective(args):
    
    method, opt = args
    
    if method == 'random':
        X_train, y_train = skutils.random_subset(
            X, y, dims=[(0, opt['fzeros']), (1, 1.0)], seed=int(opt['seed']))
    else:
         X_train, y_train = X, y
    
    folds = skutils.folds(y_train, n_folds=4, stratified=True, random_state=seed)
    
    test_mean, test_std, train_mean, train_std = cross_validate_xgb(
        X_train, y_train, params, fit_params, folds=folds)
    
    print("Cross validation test-auc-mean score %.8f (+- %.8f)" % (test_mean, test_std))
    print("Cross validation train-auc-mean score %.8f (+- %.8f)" % (train_mean, train_std))

    return {
        'loss': 1 - test_mean,
        'loss_variance': test_std**2,
        'status': STATUS_OK,
        
        # Custom data
        'acu-test-mean': test_mean,
        'acu-test-std': test_std,
        'acu-train-mean': train_mean,
        'acu-train-std': train_std,
    } 

trials = Trials()

# Needs latest hyperopt from chaosmail
# https://github.com/chaosmail/hyperopt
# https://github.com/hyperopt/hyperopt/issues/234
best = fmin(fn=objective, space=space, algo=rand.suggest, max_evals=50, trials=trials)

# Print the best result
print(best)
# Out:
# Cross validation test-auc-mean score 0.83886516 (+- 0.00580546)
# Cross validation train-auc-mean score 0.86692373 (+- 0.00129910)
# Cross validation test-auc-mean score 0.83731181 (+- 0.00621860)
# Cross validation train-auc-mean score 0.86666106 (+- 0.00072476)
# Cross validation test-auc-mean score 0.83836851 (+- 0.00367987)
# Cross validation train-auc-mean score 0.86595117 (+- 0.00132393)
# Cross validation test-auc-mean score 0.83669359 (+- 0.00791563)
# Cross validation train-auc-mean score 0.86522596 (+- 0.00236773)
# Cross validation test-auc-mean score 0.83712399 (+- 0.00618422)
# Cross validation train-auc-mean score 0.86471783 (+- 0.00217692)
# Cross validation test-auc-mean score 0.83852269 (+- 0.00589564)
# Cross validation train-auc-mean score 0.86724187 (+- 0.00164061)
# Cross validation test-auc-mean score 0.83776485 (+- 0.00717386)
# Cross validation train-auc-mean score 0.86684070 (+- 0.00218461)
# Cross validation test-auc-mean score 0.83706596 (+- 0.00894993)
# Cross validation train-auc-mean score 0.86348478 (+- 0.00314844)
# Cross validation test-auc-mean score 0.83841718 (+- 0.00490796)
# Cross validation train-auc-mean score 0.86587337 (+- 0.00235588)
# Cross validation test-auc-mean score 0.83797960 (+- 0.00656753)
# Cross validation train-auc-mean score 0.86768554 (+- 0.00253962)
# Cross validation test-auc-mean score 0.82265107 (+- 0.02492128)
# Cross validation train-auc-mean score 0.85243800 (+- 0.02201078)
# Cross validation test-auc-mean score 0.83824037 (+- 0.00326503)
# Cross validation train-auc-mean score 0.86761588 (+- 0.00139199)
# Cross validation test-auc-mean score 0.83792815 (+- 0.00715237)
# Cross validation train-auc-mean score 0.86382989 (+- 0.00403942)
# Cross validation test-auc-mean score 0.83726651 (+- 0.00616843)
# Cross validation train-auc-mean score 0.86611537 (+- 0.00216554)
# Cross validation test-auc-mean score 0.83928026 (+- 0.00249831)
# Cross validation train-auc-mean score 0.86512847 (+- 0.00055410)
# Cross validation test-auc-mean score 0.83572270 (+- 0.00399986)
# Cross validation train-auc-mean score 0.86421205 (+- 0.00126520)
# Cross validation test-auc-mean score 0.83978895 (+- 0.00633829)
# Cross validation train-auc-mean score 0.86386899 (+- 0.00234691)
# Cross validation test-auc-mean score 0.83883256 (+- 0.01239794)
# Cross validation train-auc-mean score 0.86569116 (+- 0.00378218)
# Cross validation test-auc-mean score 0.83893285 (+- 0.00694545)
# Cross validation train-auc-mean score 0.86766661 (+- 0.00223764)
# Cross validation test-auc-mean score 0.83808258 (+- 0.00419262)
# Cross validation train-auc-mean score 0.86556057 (+- 0.00139813)
# Cross validation test-auc-mean score 0.83803056 (+- 0.00268462)
# Cross validation train-auc-mean score 0.86599694 (+- 0.00068310)
# Cross validation test-auc-mean score 0.83873599 (+- 0.00541768)
# Cross validation train-auc-mean score 0.86459808 (+- 0.00078929)
# Cross validation test-auc-mean score 0.83614059 (+- 0.00733090)
# Cross validation train-auc-mean score 0.86883640 (+- 0.00142198)
# Cross validation test-auc-mean score 0.83843419 (+- 0.00426094)
# Cross validation train-auc-mean score 0.86615633 (+- 0.00074503)
# Cross validation test-auc-mean score 0.83931380 (+- 0.00998018)
# Cross validation train-auc-mean score 0.86665772 (+- 0.00297293)
# Cross validation test-auc-mean score 0.83854265 (+- 0.00311126)
# Cross validation train-auc-mean score 0.86464103 (+- 0.00098587)
# Cross validation test-auc-mean score 0.83836954 (+- 0.00526397)
# Cross validation train-auc-mean score 0.86747467 (+- 0.00214879)
# Cross validation test-auc-mean score 0.83808028 (+- 0.00203768)
# Cross validation train-auc-mean score 0.86556748 (+- 0.00110727)
# Cross validation test-auc-mean score 0.83960431 (+- 0.00334218)
# Cross validation train-auc-mean score 0.86513939 (+- 0.00057289)
# Cross validation test-auc-mean score 0.83683369 (+- 0.00607513)
# Cross validation train-auc-mean score 0.86490682 (+- 0.00155978)
# Cross validation test-auc-mean score 0.83831703 (+- 0.00778541)
# Cross validation train-auc-mean score 0.86574302 (+- 0.00261145)
# Cross validation test-auc-mean score 0.83890283 (+- 0.00803691)
# Cross validation train-auc-mean score 0.86472172 (+- 0.00201978)
# Cross validation test-auc-mean score 0.83803688 (+- 0.00363359)
# Cross validation train-auc-mean score 0.86541909 (+- 0.00101629)
# Cross validation test-auc-mean score 0.83639430 (+- 0.00620294)
# Cross validation train-auc-mean score 0.86464528 (+- 0.00152497)
# Cross validation test-auc-mean score 0.83782189 (+- 0.01048562)
# Cross validation train-auc-mean score 0.86589735 (+- 0.00162974)
# Cross validation test-auc-mean score 0.83806209 (+- 0.00372325)
# Cross validation train-auc-mean score 0.86574907 (+- 0.00232858)
# Cross validation test-auc-mean score 0.83969125 (+- 0.00725869)
# Cross validation train-auc-mean score 0.86707493 (+- 0.00213639)
# Cross validation test-auc-mean score 0.83684114 (+- 0.00483033)
# Cross validation train-auc-mean score 0.86584766 (+- 0.00096101)
# Cross validation test-auc-mean score 0.83795910 (+- 0.00180323)
# Cross validation train-auc-mean score 0.86671221 (+- 0.00037142)
# Cross validation test-auc-mean score 0.83943211 (+- 0.00828181)
# Cross validation train-auc-mean score 0.86454723 (+- 0.00294722)
# Cross validation test-auc-mean score 0.83812420 (+- 0.00619721)
# Cross validation train-auc-mean score 0.86605701 (+- 0.00196205)
# Cross validation test-auc-mean score 0.83840215 (+- 0.00582109)
# Cross validation train-auc-mean score 0.86560808 (+- 0.00220832)
# Cross validation test-auc-mean score 0.83844418 (+- 0.00714099)
# Cross validation train-auc-mean score 0.86502523 (+- 0.00171736)
# Cross validation test-auc-mean score 0.83897002 (+- 0.00599552)
# Cross validation train-auc-mean score 0.86473931 (+- 0.00169526)
# Cross validation test-auc-mean score 0.83853689 (+- 0.00314074)
# Cross validation train-auc-mean score 0.86698277 (+- 0.00061068)
# Cross validation test-auc-mean score 0.83829815 (+- 0.00291994)
# Cross validation train-auc-mean score 0.86578386 (+- 0.00151710)
# Cross validation test-auc-mean score 0.83913705 (+- 0.00288634)
# Cross validation train-auc-mean score 0.86504641 (+- 0.00173841)
# Cross validation test-auc-mean score 0.83565425 (+- 0.00655948)
# Cross validation train-auc-mean score 0.86355279 (+- 0.00367929)
# Cross validation test-auc-mean score 0.83652425 (+- 0.00432872)
# Cross validation train-auc-mean score 0.86531918 (+- 0.00058110)
# Cross validation test-auc-mean score 0.83795040 (+- 0.00710103)
# Cross validation train-auc-mean score 0.86604770 (+- 0.00215988)
# {'method': 0, 'seed': 627297.0, 'fzeros': 0.99387885958024613}

# %%
sorted_trials = sorted(trials.trials, key=lambda trial: trial['result']['loss'])

scores = sorted_trials[0]['result']

print("Cross validation test-auc-mean score %.8f (+- %.8f)" % (scores['acu-test-mean'], scores['acu-test-std']))
print("Cross validation train-auc-mean score %.8f (+- %.8f)" % (scores['acu-train-mean'], scores['acu-train-std']))
print(best)
# Out:
# Cross validation test-auc-mean score 0.83978895 (+- 0.00633829)
# Cross validation train-auc-mean score 0.86386899 (+- 0.00234691)
# {'method': 0, 'seed': 627297.0, 'fzeros': 0.99387885958024613}
